# %%
import pandas as pd
from deserializer import NFeJsonDeserializer

# %%
# Instantiate the class and pass the path to the directory with NFe JSON documents.
nfe_reader = NFeJsonDeserializer("data/")

# %%
# List avaliable files in the directory.
nfe_reader.list_files()
# Out:
# ['data.json']

# %%
# Example deserialize JSON by using the placeholder name for the dataframe
nfe_reader.get_dataframe(filename="data.json", dataframe="nfe_info")
# Out:
#                CreateDate         EmissionDate  Discount  NFeNumber  NFeID
# 0  2021-05-24T20:21:34.79  2021-05-24T00:00:00       0.0        501      1
# 1  2021-05-24T20:21:34.79  2021-05-24T00:00:00       0.0        502      2
# 2  2021-05-24T20:21:34.79  2021-05-24T00:00:00       0.0        503      3

# %%
# Example deserialize JSON by using the placeholder name for the dataframe
nfe_reader.get_dataframe(filename="data.json", dataframe="item_list")
# Out:
#    NFeID   ProductName  Value  Quantity
# 0      1          Rice  35.55         2
# 1      1         Flour  11.55         5
# 2      1          Bean  27.15         7
# 0      2        Tomate  12.25        10
# 1      2         Pasta   7.55         5
# 0      3          Beer   9.00         6
# 1      3  French fries  10.99         2
# 2      3     Ice cream  27.15         1

# %%
# Example deserialize JSON by default get_dataframe return.
nfe_reader.get_dataframe(filename="data.json")[0]
# Out:
#                CreateDate         EmissionDate  Discount  NFeNumber  NFeID
# 0  2021-05-24T20:21:34.79  2021-05-24T00:00:00       0.0        501      1
# 1  2021-05-24T20:21:34.79  2021-05-24T00:00:00       0.0        502      2
# 2  2021-05-24T20:21:34.79  2021-05-24T00:00:00       0.0        503      3

# %%
# Example deserialize JSON by default get_dataframe return.
nfe_reader.get_dataframe(filename="data.json")[1]
# Out:
#    NFeID   ProductName  Value  Quantity
# 0      1          Rice  35.55         2
# 1      1         Flour  11.55         5
# 2      1          Bean  27.15         7
# 0      2        Tomate  12.25        10
# 1      2         Pasta   7.55         5
# 0      3          Beer   9.00         6
# 1      3  French fries  10.99         2
# 2      3     Ice cream  27.15         1

# %%
# Example concateneted dataframe from JSON NFe document.
nf_info = nfe_reader.get_dataframe(filename="data.json")[0]
itemlist = nfe_reader.get_dataframe(filename="data.json")[1]

pd.merge(nf_info, itemlist, "inner", "NFeID")
# Out:
#                CreateDate         EmissionDate  Discount  NFeNumber  NFeID  \
# 0  2021-05-24T20:21:34.79  2021-05-24T00:00:00       0.0        501      1
# 1  2021-05-24T20:21:34.79  2021-05-24T00:00:00       0.0        501      1
# 2  2021-05-24T20:21:34.79  2021-05-24T00:00:00       0.0        501      1
# 3  2021-05-24T20:21:34.79  2021-05-24T00:00:00       0.0        502      2
# 4  2021-05-24T20:21:34.79  2021-05-24T00:00:00       0.0        502      2
# 5  2021-05-24T20:21:34.79  2021-05-24T00:00:00       0.0        503      3
# 6  2021-05-24T20:21:34.79  2021-05-24T00:00:00       0.0        503      3
# 7  2021-05-24T20:21:34.79  2021-05-24T00:00:00       0.0        503      3
#
#     ProductName  Value  Quantity
# 0          Rice  35.55         2
# 1         Flour  11.55         5
# 2          Bean  27.15         7
# 3        Tomate  12.25        10
# 4         Pasta   7.55         5
# 5          Beer   9.00         6
# 6  French fries  10.99         2
# ...
